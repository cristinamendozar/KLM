# %%
import IPython.core.display as di

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients')
sns.lmplot(x="EGTM", y="dEta_is_c_LPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dWc_c_LPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dEta_is_d_LPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dWc_d_LPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dEta_is_HPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dWc_HPC_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dEta_is_HPT_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dWc_HPT_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dEta_is_LPT_1", data=df, hue="EGT_GROUP", fit_reg=False)
sns.lmplot(x="EGTM", y="dWc_LPT_1", data=df, hue="EGT_GROUP", fit_reg=False)

# %%
import pandas as pd
df=pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx',
                   'KLM&Clients')

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
from pandas import Series, DataFrame, Panel

df.time = pd.to_datetime(df.DATE, format='%Y-%m-%d')
df.set_index(df.DATE, inplace=True)


df[['DATE','EGTM']].set_index('DATE').groupby(df['Owner']).plot()

df[['EGTM']].groupby(df['Owner']).boxplot()
# Out:
# CLIENT         Axes(0.1,0.15;0.363636x0.75)
# KLM       Axes(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
df[['EGTM']].groupby(df['Grouping']).boxplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-380ebdf75bf4> in <module>()
# ----> 1 df[['EGTM']].groupby(df['Grouping']).boxplot()
#
# NameError: name 'df' is not defined

# %%
sns.kdeplot(df['CSN'])

# %%
sns.kdeplot(df['EGTM'])

# %%
with sns.axes_style("white"):
    sns.jointplot(x=df['CSN'], y=df['EGTM'],kind="hex", color="k", gridsize=20)

# %%
sns.jointplot(x=df['CSN'], y=df['EGTM'], kind="kde")

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients')
with sns.axes_style("white"):
    hexplot = sns.jointplot(x=df['EGTM'], y=df['dEta_is_HPC_1'],kind="hex", color="k", gridsize=15)
    cax = hexplot.fig.add_axes([0.90, 0.25, 0.02, 0.4])
    sns.plt.colorbar(cax=cax)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

sns.lmplot(x="CSN", y="dEta_is_HPC_1", data=df, hue="EGT_GROUP", palette=dict(GOOD="k",BAD="r"), legend=False)

red_patch = mpatches.Patch(color='red', label='Bad')
black_patch = mpatches.Patch(color='black', label='Good')
plt.legend(handles=[red_patch,black_patch])

plt.show()

# %%
sns.lmplot(x="FLIGHT LEG", y="dWc_HPC_1", data=df, hue="EGT_GROUP", palette=dict(GOOD="k",BAD="r"), legend=False)

red_patch = mpatches.Patch(color='red', label='Bad')
black_patch = mpatches.Patch(color='black', label='Good')
plt.legend(handles=[red_patch,black_patch])

plt.show()

# %%
sns.lmplot(x="FLIGHT LEG", y="dEta_is_HPT_1", data=df, hue="EGT_GROUP", palette=dict(GOOD="k",BAD="r"), legend=False)

red_patch = mpatches.Patch(color='red', label='Bad')
black_patch = mpatches.Patch(color='black', label='Good')
plt.legend(handles=[red_patch,black_patch])

plt.show()

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib import gridspec

font = {'family' : 'Calibri',
        'size'   : 15}

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx',
                   'Factory New (A3)')

x = pd.Series(df['DATE'])
y = pd.Series(df['EGTM'])

f = plt.figure(figsize=(8,6))
gs = gridspec.GridSpec(1,2, width_ratios=[6,1])
plt.grid(axis='y', which="major", linestyle='dotted', linewidth=0.4)

ax1 = plt.subplot(gs[0])
ax1.set(xlabel=('DATE'),ylabel=('EGTM($^\circ$C)'))
ax1.plot_date(x , y, fmt="ko-", markersize=3.5, linewidth=0.85)
ax1.xaxis.label.set_size(13)
ax1.yaxis.label.set_size(13)
ax1.tick_params(axis='both', labelsize=13)

ax2 = plt.subplot(gs[1])
ax2.set(xlabel='n=72\n mean=29.76\n std.Dev=8.15')
ax2.boxplot(df['EGTM'], showmeans=True, widths = 0.6, sym='k.')
ax2.xaxis.label.set_size(13)
ax2.tick_params(axis='both', labelsize=1)

f.suptitle('Factory New CF6-80E1 Engines')

plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import matplotlib

font = {'family' : 'Calibri',
        'size'   : 15}

matplotlib.rc('font', **font)

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx',
                   '1SV(KLM&Clients)')
with sns.axes_style("white"):
    hexplot = sns.jointplot(x=df['CSN'], y=df['TSN'],kind="hex", color="k", gridsize=15, stat_func=None)
    cax = hexplot.fig.add_axes([0.90, 0.25, 0.02, 0.4])
    cbar = sns.plt.colorbar(cax=cax)
    cbar.set_label('# of Samples')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import matplotlib

font = {'family' : 'Calibri',
        'size'   : 15}

matplotlib.rc('font', **font)

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx',
                   '1SV(KLM&Clients)')


y = pd.Series(df['TSN'], name = "Time Since New (Hrs)")
x = pd.Series(df['EGTM'], name = "EGTM($^\circ$C)")

sns.regplot(x=x,y=y, fit_reg=False)

plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients')

#sns.lmplot(x="FLIGHT LEG", y="EGTM", data=df, hue="EGT_GROUP", palette=dict(GOOD="k",BAD="r"), legend=False)

x = pd.Series(df['FLIGHT LEG'], name = "Flight Leg (CSN/TSN)")
y = pd.Series(df['dEta_is_HPC_1'], name = "HPC")

fig = plt.figure()
sns.set_style("ticks")
g = sns.JointGrid(x,y)
g.plot_marginals(sns.distplot,color=".5")
g.plot_joint(plt.hexbin,gridsize=10, cmap="viridis")
cax = g.fig.add_axes([0.90, 0.25, 0.02, 0.4])
cbar = sns.plt.colorbar(cax=cax)
cbar.set_label('# of Samples')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   '1st')

sns.lmplot(x="FLIGHT LEG", y="dEta_is_HPC_1", data=df, hue="EGT_GROUP", legend=False, fit_reg=True)

#red_patch = mpatches.Patch(color='red', label='Bad')
#black_patch = mpatches.Patch(color='black', label='Good')
#plt.legend(handles=[red_patch,black_patch])

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   '2nd')

sns.lmplot(x="FLIGHT LEG", y="dEta_is_HPC_1", data=df, hue="EGT_GROUP", legend=False, fit_reg=False)

#red_patch = mpatches.Patch(color='red', label='Bad')
#black_patch = mpatches.Patch(color='black', label='Good')
#plt.legend(handles=[red_patch,black_patch])

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx',
                   '1SV(KLM&Clients)')

#sns.lmplot(y="FLIGHT LEG", x="EGTM", data=df, hue="EGT_GROUP", legend=False, fit_reg=False)

#red_patch = mpatches.Patch(color='red', label='Bad')
#black_patch = mpatches.Patch(color='black', label='Good')
#plt.legend(handles=[red_patch,black_patch])
fig = plt.figure()
sns.set_style("ticks")
g = sns.JointGrid(df['FLIGHT LEG'],df['EGTM'])
g.plot_marginals(sns.distplot,color=".5")
g.plot_joint(plt.hexbin,gridsize=15, cmap="viridis")
cax = g.fig.add_axes([0.90, 0.25, 0.02, 0.4])
cbar = sns.plt.colorbar(cax=cax)
cbar.set_label('# of Samples')

plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="FLIGHT LEG", y="dEta_is_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='Bad')
black_patch = mpatches.Patch(color='black', label='Good')
blue_patch = mpatches.Patch(color='blue',label='Regular')
plt.legend(handles=[black_patch,blue_patch,red_patch])
plt.xlabel('Flight Leg (hr/cycle)',fontsize=13)
plt.ylabel('$\Delta\eta$ HPC',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/01 EGTM Data Base Plots and Analysis.xlsx','KLM&Clients')
plt.hist(df['EGTM'], bins=10,normed=False, alpha=0.5, histtype='stepfilled', color='steelblue',edgecolor='none')
plt.grid(b=None, which='both', axis='both')

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)1SV')

plot = sns.lmplot(y="dEta_is_HPC_1 [%]", x="dWc_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
plot = sns.lmplot(y="dEta_is_HPT_1 [%]", x="dWc_HPT_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
plot = sns.lmplot(y="dEta_is_c_LPC_1 [%]", x="dWc_c_LPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(y="dEta_is_HPC_1 [%]", x="dWc_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW-Offdesign)')

plot = sns.lmplot(y="dEta_is_HPC_1 [%]", x="dWc_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="N%2 [%]", y="dWc_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=True, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(y="EGT [C]2", x="TT2 [C]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="TT2 [C]", y="N%2 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="TT2 [C]", y="W19 [kg/s]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="Humidity", y="dWc_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=True, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="Humidity", y="dEta_is_HPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=True, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="Humidity", y="dWc_d_LPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="TT2 [C]", y="dWc_d_LPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="Humidity", y="dEta_is_c_LPC_1 [%]", data=df, hue="EGT_GROUP", fit_reg=True, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'KLM&Clients(NEW)')

plot = sns.lmplot(x="Humidity", y="TT2 [C]", data=df, hue="EGT_GROUP", fit_reg=False, palette=dict(GOOD="k",BAD="r",REGULAR="b"), legend=False)
red_patch = mpatches.Patch(color='red', label='EGTM>27')
black_patch = mpatches.Patch(color='black', label='EGTM<38')
blue_patch = mpatches.Patch(color='blue',label='28<EGTM<37')
plt.legend(handles=[black_patch,blue_patch,red_patch])
#plt.xlabel('EGTM (C)',fontsize=13)
#plt.ylabel('FN (lbs)',fontsize=13)
plt.show()
