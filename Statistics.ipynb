# %% [markdown]
# - checar la normalizacion de mi data
# - checar si realmente tengo que hacer la division entre los grupos
# - cuales son mis factores y cuales son mis variables?
# - blocking factors theory
# - shapiro wilk test para normalizacion de mi data
# - que pedo? si mi data es una muestra pq debo de saber si esta normalizada o no?

# %% [markdown]
# Shapiro Test

# %%
# %matplotlib inline
from scipy import stats
import pandas as pd

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')

f_val, p_val = stats.f_oneway(df['dEta_is_HPC_1 [%]'], df2['dEta_is_HPC_1 [%]'], df3['dEta_is_HPC_1 [%]'] )

print "One-way ANOVA P =", p_val
# Out:
# One-way ANOVA P = nan
# c:\users\klm76343\appdata\local\continuum\anaconda2\lib\site-packages\scipy\stats\stats.py:2974: RuntimeWarning: invalid value encountered in double_scalars
#   msb = ssbn / float(dfbn)

# %% [markdown]
# The test rejects the hypothesis of normality when the p-value is less than or equal to 0.05.  Failing the normality test allows you to state with 95% confidence the data does not fit the normal distribution.  Passing the normality test only allows you to state no significant departure from normality was found.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')
df2 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'BAD')
df3 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'REGULAR')

ax1 = sns.distplot(df['dEta_is_HPC_1 [%]'], color="black", kde=False, fit=stats.gamma)
ax2 = sns.distplot(df2['dEta_is_HPC_1 [%]'], color="red", kde=False, fit=stats.gamma)
ax3 = sns.distplot(df3['dEta_is_HPC_1 [%]'], color="blue", kde=False, fit=stats.gamma)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')
df2 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'BAD')
df3 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'REGULAR')

sns.kdeplot(df['dEta_is_c_LPC_1 [%]'], color="black", shade=True, bw=0.2)
sns.kdeplot(df2['dEta_is_c_LPC_1 [%]'], color="red", shade=True, bw=.2)
sns.kdeplot(df3['dEta_is_c_LPC_1 [%]'], color="blue", shade=True, bw=.2)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')
df2 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'BAD')
df3 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'REGULAR')

ax1 = sns.kdeplot(df['dEta_is_HPC_1 [%]'], color="black", shade=True, bw=0.2)#, cut=0)
ax2 = sns.kdeplot(df2['dEta_is_HPC_1 [%]'], color="red", shade=True, bw=.2)#, cut=0)
ax3 = sns.kdeplot(df3['dEta_is_HPC_1 [%]'], color="blue", shade=True, bw=.2)#, cut=0)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')
df2 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'BAD')
df3 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'REGULAR')

sns.kdeplot(df['dEta_is_HPT_1 [%]'], color="black", shade=True, bw=0.2)
sns.kdeplot(df2['dEta_is_HPT_1 [%]'], color="red", shade=True, bw=.2)
sns.kdeplot(df3['dEta_is_HPT_1 [%]'], color="blue", shade=True, bw=.2)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

df = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'GOOD')
df2 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'BAD')
df3 = pd.read_excel('//kl1015cy/home$/klm76343/Desktop/000 Thesis/01 KLM/01 Documents/02 EXCEL/02 AM Simulation.xlsx',
                   'REGULAR')

sns.kdeplot(df['dEta_is_LPT_1 [%]'], color="black", shade=True, bw=0.2)
sns.kdeplot(df2['dEta_is_LPT_1 [%]'], color="red", shade=True, bw=.2)
sns.kdeplot(df3['dEta_is_LPT_1 [%]'], color="blue", shade=True, bw=.2)
